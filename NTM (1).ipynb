# %%
# !pip install wordcloud > /dev/null
# !pip install msgpack > /dev/null
# !pip install nltk > /dev/null
# !pip install mxnet > /dev/null
# Out:
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import boto3
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import os
import pandas as pd
import re
import sagemaker
import scipy.sparse as sparse
import seaborn as sns
import time
import warnings

from scipy import interpolate
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from wordcloud import WordCloud

# %matplotlib inline
warnings.filterwarnings('ignore')

role = sagemaker.get_execution_role()
sagemaker_session = sagemaker.Session()

# %%
raw_data_filename = 'cleaned.csv'

df = pd.read_csv(raw_data_filename, parse_dates=[6])
df.head()
# Out:
#                     id                                          tweet_url  \
# 0  1230472014130892800  https://twitter.com/digit96/status/12304720141...
# 1  1230472009605406720  https://twitter.com/coronahelps/status/1230472...
# 2  1230472003301335041  https://twitter.com/tr1897gmailcom3/status/123...
# 3  1230472001439051776  https://twitter.com/meste48/status/12304720014...
# 4  1230471998704422913  https://twitter.com/Starid23/status/1230471998...
#
#                        created_at          parsed_created_at user_screen_name  \
# 0  Thu Feb 20 12:39:23 +0000 2020  2020-02-20T12:39:23+00:00          digit96
# 1  Thu Feb 20 12:39:22 +0000 2020  2020-02-20T12:39:22+00:00      coronahelps
# 2  Thu Feb 20 12:39:21 +0000 2020  2020-02-20T12:39:21+00:00  tr1897gmailcom3
# 3  Thu Feb 20 12:39:20 +0000 2020  2020-02-20T12:39:20+00:00          meste48
# 4  Thu Feb 20 12:39:20 +0000 2020  2020-02-20T12:39:20+00:00         Starid23
#
#                                                 text tweet_type coordinates  \
# 0  RT @W7VOA: #Singapore confirms first case with...    retweet         NaN
# 1  #BREAKING: YouTube video about the CDC hiding ...   original         NaN
# 2  1. Wuhan  2. Qom, Iran 3. Daegu, South Korea 4...   original         NaN
# 3  RT @BogochIsaac: Two elderly people succumbed ...    retweet         NaN
# 4  RT @Finanzas_Time: #Coronavirus #COVID19 ☣️  C...    retweet         NaN
#
#                                             hashtags  \
# 0               Singapore COVID19 coronavirus dengue
# 1  BREAKING coronavirus WuhanCoronavirus COVID19 ...
# 2                                coronavirus COVID19
# 3                                            covid19
# 4                                Coronavirus COVID19
#
#                                              media  ... user_favourites_count  \
# 0                                              NaN  ...                  7856
# 1  https://pbs.twimg.com/media/ERODw_dWAAMcsum.png  ...                    22
# 2                                              NaN  ...                     3
# 3                                              NaN  ...                  5279
# 4                                              NaN  ...                    64
#
#    user_followers_count user_friends_count  user_listed_count  \
# 0                  1933                783                 48
# 1                     4                 16                  0
# 2                     8                166                  0
# 3                  1530               2724                 64
# 4                     7                 98                  0
#
#                     user_location           user_name user_statuses_count  \
# 0  서울특별시 동대문구& 東京都 目黒区& 부산광역시 수영구      종이나무 Papertree              368281
# 1                             NaN         Coronahelps                  35
# 2                      Weston, FL            Tom Ryan                  47
# 3                             NaN  maria eugenia este               39776
# 4                      Lima, Peru       Cesar Gamarra                 344
#
#   user_time_zone  user_urls  user_verified
# 0            NaN        NaN          False
# 1            NaN        NaN          False
# 2            NaN        NaN          False
# 3            NaN        NaN          False
# 4            NaN        NaN          False
#
# [5 rows x 37 columns]

# %% [markdown]
# We have 20 columns:
# id
# tweet_url
# created_at
# parsed_created_at
# user_screen_name
# text
# tweet_type
# coordinates
# hashtags
# media
# user_favourites_count
# user_followers_count
# user_friends_count
# user_listed_count
# user_location
# user_name
# user_statuses_count
# user_time_zone
# user_urls

# %%
def clean_tweet(text): 
   ext = "http" 
   tweet = text[:text.find(ext)].lower() 
   tweet = re.sub("[^\S]", " ", tweet) 
   tweet = re.sub("english translation ", "", tweet) 
   textOnly = re.sub("[^a-zA-Z0-9@# ]", "", tweet) 
   return(textOnly)

# %%
df.texts = df.text.apply(lambda x: clean_tweet)

# %%
keep_col = ['id', 'parsed_created_at', 'user_screen_name', 'text','user_followers_count','user_statuses_count', 'tweet_type', 'coordinates', 'hashtags', 'user_location', 'user_name', 'user_verified']

# %%
df[keep_col]
# Out:
#                          id          parsed_created_at user_screen_name  \
# 0       1230472014130892800  2020-02-20T12:39:23+00:00          digit96
# 1       1230472009605406720  2020-02-20T12:39:22+00:00      coronahelps
# 2       1230472003301335041  2020-02-20T12:39:21+00:00  tr1897gmailcom3
# 3       1230472001439051776  2020-02-20T12:39:20+00:00          meste48
# 4       1230471998704422913  2020-02-20T12:39:20+00:00         Starid23
# 5       1230471997559394306  2020-02-20T12:39:19+00:00         AmitTrds
# 6       1230471992618475520  2020-02-20T12:39:18+00:00        no10chico
# 7       1230471982296100864  2020-02-20T12:39:16+00:00   Miruku43780816
# 8       1230471979519631360  2020-02-20T12:39:15+00:00     Chineinfocom
# 9       1230471977460273152  2020-02-20T12:39:15+00:00        mpimnapas
# 10      1230471970573164544  2020-02-20T12:39:13+00:00  awkwardcheftrng
# 11      1230471970396852225  2020-02-20T12:39:13+00:00  e9blkPjlD4Fm1lw
# 12      1230471970212524039  2020-02-20T12:39:13+00:00  michelle1129591
# 13      1230471968656326656  2020-02-20T12:39:13+00:00        llacigart
# 14      1230471967876059136  2020-02-20T12:39:12+00:00    Jenny74940884
# 15      1230471961979052038  2020-02-20T12:39:11+00:00       guillochan
# 16      1230471961375133697  2020-02-20T12:39:11+00:00        bartrulez
# 17      1230471950088253445  2020-02-20T12:39:08+00:00     ArteryPound_
# 18      1230471934875488256  2020-02-20T12:39:04+00:00          amizere
# 19      1230471930433744896  2020-02-20T12:39:03+00:00        mrAtubila
# 20      1230471926012764160  2020-02-20T12:39:02+00:00         tytylzy7
# 21      1230471925849370626  2020-02-20T12:39:02+00:00  ministeriosalud
# 22      1230471923655696387  2020-02-20T12:39:02+00:00    HayatAliAlpha
# 23      1230471913815732224  2020-02-20T12:38:59+00:00  janeofthewester
# 24      1230471900859682818  2020-02-20T12:38:56+00:00      av_anshuman
# 25      1230471872950697984  2020-02-20T12:38:50+00:00    cristina3popa
# 26      1230471858392158211  2020-02-20T12:38:46+00:00       rodmagat14
# 27      1230471826859548678  2020-02-20T12:38:39+00:00        vivi_lera
# 28      1230471824196145152  2020-02-20T12:38:38+00:00    villordo_raul
# 18                                     covid19 nCoVAfrica
# 19                                                COVID19
# 20                                            ZhangYixing
# 21                                               LaSerena
# 22                                                COVID19
# 23      武汉疫情 武汉 武汉肺炎 武汉肺炎 CoronaOutbreak CoronaOutbrea...
# 24                                                  China
# 25                                                COVID19
# 26                                            coronavirus
# 27                                            ZhangYixing
# 28                                    coronavirus COVID19
# 29                               Coronavirus COVID19 武汉肺炎
# ...                                                   ...
# 179868                                                NaN
# 179869                                     isciii covid19
# 179870                         COVID19 Corona Coronavirus
# 179871                                                NaN
# 179872                                        coronavirus
# 179873                                coronavirus covid19
# 179874                                                NaN
# 179875                                     ARASHI 嵐 Weibo
# 179876                                                NaN
# 179877                                                NaN
# 179878                                COVID19 coronavirus
# 179879                                            COVID19
# 179880                    Chine Hubei Coronavirus COVID19
# 179881                                                NaN
# 179882                                coronavirus covid19
# 179883                                        coronavirus
# 179884                                    SNS coronavirus
# 179885                                        coronavirus
# 179886                    coronavirus HearUsSeeUs COVID19
# 179887                                        coronavirus
# 179888                                        coronavirus
# 179889                                                NaN
# 179890                                                NaN
# 179891                                                NaN
# 179892                                                NaN
# 179893                                                NaN
# 179894                                                NaN
# 179895                                Coronavirus COVID19
# 179896                                           SARSCoV2
# 179897                                                NaN
#
#                          user_location  \
# 0       서울특별시 동대문구& 東京都 目黒区& 부산광역시 수영구
# 1                                  NaN
# 2                           Weston, FL
# 3                                  NaN
# 4                           Lima, Peru
# 5                                India
# 6                             redditch
# 7                            Hong Kong
# 8                                  NaN
# 9                       United Kingdom
# 10               Somewhere in Brampton
# 11                                 NaN
# 12                   Pennsylvania, USA
# 13                         atlanta•ish
# 14                                 NaN
# 15                                 NaN
# 16                        Stamford, CT
# 17                                2025
# 18                              Malawi
# 19                       Kumasi, Ghana
# 20                             Japan🇯🇵
# 21                               Chile
# 22                        Brooklyn, NY
# 23                                 NaN
# 24                    New Delhi, India
# 25           Woodbridge Ontario Canada
# 26         Republic of the Philippines
# 27                          EX9 Planet
# 28                      Luque Paraguay
# 29                           Hong Kong
# ...                                ...
# 179868                             NaN
# 179869       Manzanares El Real, Spain
# 179870                         bangkok
# 179871                           india
# 179872              île de la réunion
# 179873                             NaN
# 179874                          France
# 179875                             NaN
# 179876                        Thailand
# 179877    Ciudad de México Mi 💕 en Qro
# 179878                          Sydney
# 179879    Ciudad de México Mi 💕 en Qro
# 179880                             NaN
# 179881                             NaN
# 179882                             NaN
# 179883    Ciudad de México Mi 💕 en Qro
# 179884  Principado de Asturias, España
# 179885         Besançon, Franche-Comté
# 179886                    South Africa
# 179887                    Nice, France
# 179888    Ciudad de México Mi 💕 en Qro
# 179889                             NaN
# 179890    Ciudad de México Mi 💕 en Qro
# 179891                             NaN
# 179892                   Camarillo, Ca
# 179893                              地球
# 179894                   still alive 🌻
# 179895                             NaN
# 179896             Penticton Canada BC
# 179897                             NaN
#
#                                       user_name  user_verified
# 0                                종이나무 Papertree          False
# 1                                   Coronahelps          False
# 2                                      Tom Ryan          False
# 3                            maria eugenia este          False
# 4                                 Cesar Gamarra          False
# 5                                     Amit Jain          False
# 6                              redditchgardener          False
# 7                        Love freedom democracy          False
# 8                                Chine-info.com          False
# 9                                            mm          False
# 10                                  tammy gomes          False
# 11                                           金马          False
# 12                             Michelle Barnett          False
# 13                                 ⏳carol muse⏳          False
# 14                                        Jenny          False
# 15                               Guillermo Chan          False
# 16                                    Bart Rule          False
# 17                                            🍑          False
# 18                                 Agnes Mizere          False
# 19                                          IA9          False
# 20                                yuka*🐝🐑X'back          False
# 21                          Ministerio de Salud           True
# 22                                  Gen X Lefty          False
# 23                                    Jane West          False
# 24                                     anshuman          False
# 25                                Cristina Popa          False
# 26                                    Rod Magat          False
# 27                   ǷᎥՈƘʎ_ŁᎥɠҺ੮ Chen⚡첸❃백현이 𝓮𝔁𝓸          False
# 28                         Raúl Carlos Villordo          False
# 29                                     Jack Soh          False
# ...                                         ...            ...
# 179868                              jose manuel          False
# 179869                               David Peck          False
# 179870                               pimsri@ROK          False
# 179871                                      PDA          False
# 179872                                    Valou          False
# 179873                              jose manuel          False
# 179874  GreenBarjφjo Mº333 ☮️ 🐝 🦍🌺🌍🐉🦞😷🌈o|o🦛🏴‍☠️          False
# 179875                         🧡super broccoli💙          False
# 179876                    งุ่งงงงงงงงิงงงงงงงิ🤪          False
# 179877                     Juan Andrés Rincón G          False
# 179878                                 Anne Luu          False
# 179879                     Juan Andrés Rincón G          False
# 179880                          Busconi Martine          False
# 179881                    Pavan Kumar Shastry🇮🇳          False
# 179882                              jose manuel          False
# 179883                     Juan Andrés Rincón G          False
# 179884                     Pablo I. Fdez. Muñiz          False
# 179885                                   Seb 🇫🇷          False
# 179886                          Quotethiswoman+          False
# 179887                                    Clem🌀          False
# 179888                     Juan Andrés Rincón G          False
# 179889                              jose manuel          False
# 179890                     Juan Andrés Rincón G          False
# 179891                                    Kaori          False
# 179892                             Lucy Buttons          False
# 179893                                  yumi　ゆみ          False
# 179894                        tabøreciara 🌷🌼🌺🌻🌹          False
# 179895                               Damiendoza          False
# 179896                          dreamvillaorion          False
# 179897                                       AF          False
#
# [179898 rows x 12 columns]

# %%
df.parsed_created_at = pd.to_datetime(df.parsed_created_at)
perhr = df.set_index(df.parsed_created_at).resample('D').count()

# %%
fig, ax = plt.subplots(figsize = (20,8))
perhr['2020-02-20':].user_statuses_count.interpolate(method='linear').plot(ax = ax, color="black", fontsize=12, alpha=0.1)
pd.DataFrame.rolling(perhr, window=7).mean().text['2020-02-20':].plot(color ='r') 
China ='2020-02-20'
AMERICA = '2020-02-20' 
ax.annotate('COVID IN CHINA',xy=(China, 200),xytext=('2020-02-20', 310), 
           arrowprops=dict(facecolor='white', shrink=0.05), size=15) 
ax.annotate('COVID IN USA',xy=(AMERICA, 200),xytext=('2020-02-20', 310), 
           arrowprops=dict(facecolor='white', shrink=0.05),size=15) 
ax.margins(None,0.1)
ax.legend(['Tweets Per Day','2-Day Rolling Average'], loc = 'upper right', 
          numpoints = 1, labelspacing = 2.0, fontsize = 14)
ax.set_xlabel('Date')
ax.set_ylabel('Number of Tweets')
plt.show()

# %% [markdown]
# KEYWORD ANALYSIS

# %%
emoticons_str = r"""
   (?:
       [:=;] # Eyes
       [oO\-]? # Nose (optional)
       [D\)\]\(\]/\\OpP] # Mouth
   )""" 
 
regex_str = [ 
   emoticons_str, 
   r'<[^>]+>', # HTML tags 
   r'(?:@[\w_]+)', # @-mentions 
   r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags 
   r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs  
   r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers 
   r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and ' 
   r'(?:[\w_]+)', # other words 
   r'(?:\S)' # anything else
]
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE) 
 
def tokenize(s): 
   return tokens_re.findall(s)
Tfidf_vectorizer = TfidfVectorizer(analyzer='word', tokenizer=tokenize, ngram_range=(1,
2), stop_words='english', 
                                  token_pattern='\\b[a-z][a-z]+\\b', max_df=.5)
tfidf_tweets = Tfidf_vectorizer.fit_transform(df.text.values.astype('U'))

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#    return false;
# }

# %%
terms = Tfidf_vectorizer.get_feature_names()
wc = WordCloud(height=1000, width=1000, max_words=1000).generate("".join(terms))
plt.figure(figsize=(10, 10))
plt.imshow(wc)
plt.axis("off")
plt.title("Keyword Word Cloud")
plt.show()

# %%
top_users = df.user_name.value_counts().sort_values(ascending=False)
top_users.head(10).plot.bar(title="Top 10 Twitter Handles", figsize=(16,8))

# %%
pd.options.mode.chained_assignment = None  
 
mentions = df.loc[df.text.str.contains('@', na=False)]
mentions['Tagged User'] = mentions.text.apply(lambda x: re.findall(r'@([A-Za-z0-9_]+)',
str(x)))
users = mentions.user_name.unique()
mentions['Tagged User Cnt'] = mentions['Tagged User'].apply(lambda x: list(set(x).intersection(users)) )
mentions['Cnt length'] = mentions['Tagged User Cnt'].apply(lambda x: len(x))  
 
for i in range(len(mentions.text)):  
   row = mentions.iloc[i,:]  
     
     
   for j in range(len(row['Tagged User'])):  
       tmp = pd.DataFrame({'User':[row['user_name']],  
                           'Mentions':[row['Tagged User'][j]],  
                           'Time': [row['parsed_created_at']],  
                           'User num status':[row['user_statuses_count']],  
                           'Followers':[row['user_followers_count']],  
                           'Weight': [1]})  
       if i==0 and j==0:  
           mention_net = tmp  
       else:  
           mention_net = mention_net.append(tmp, ignore_index=True)  
             
mention_net = mention_net[mention_net['User']!=mention_net['Mentions']].reset_index(drop=True)
mention_net.head(5)
# Out:
#                  User        Mentions                      Time  \
# 0      종이나무 Papertree           W7VOA 2020-02-20 12:39:23+00:00
# 1  maria eugenia este     BogochIsaac 2020-02-20 12:39:20+00:00
# 2       Cesar Gamarra   Finanzas_Time 2020-02-20 12:39:20+00:00
# 3           Amit Jain         bsindia 2020-02-20 12:39:19+00:00
# 4    redditchgardener  DarrenPlymouth 2020-02-20 12:39:18+00:00
#
#    User num status  Followers  Weight
# 0           368281       1933       1
# 1            39776       1530       1
# 2              344          7       1
# 3             4926        249       1
# 4            12953       1192       1

# %%
most_mentions = mention_net.Mentions.value_counts().sort_values(ascending=False)
most_active = mention_net.User.value_counts().sort_values(ascending=False)  
 
plt.figure(figsize=(16,8))
ax1 = plt.subplot(121)
ax1 = sns.barplot(most_mentions[0:9].index, most_mentions[0:9].values)
ax1 = plt.title("Most Mentioned Handles")
ax1 =plt.xticks(rotation=90)
ax2 = plt.subplot(122)
ax2 = sns.barplot(most_active[0:9].index, most_active[0:9].values)
ax2 = plt.title("Most Active Handles")
ax2 =plt.xticks(rotation=90)
plt.show()

# %%
network = mention_net.iloc[:,[0,1,5]] #Use the mentions, user, and weight columns to bulid the network
print(network)
network = network.groupby(by=['Mentions','User'],as_index='False')['Weight'].sum().reset_index(name='Weight')
network= pd.DataFrame(network).sort_values(by='Weight',ascending=False).reset_index(drop=True)
network = network[network['Weight']>20]  
 
print('Most frequent user/mention pairs:')
network.head(10)
# Out:
#                               User         Mentions  Weight
# 0                   종이나무 Papertree            W7VOA       1
# 1               maria eugenia este      BogochIsaac       1
# 2                    Cesar Gamarra    Finanzas_Time       1
# 3                        Amit Jain          bsindia       1
# 4                 redditchgardener   DarrenPlymouth       1
# 5           Love freedom democracy       HongKongFP       1
# 6                               mm      kingjames_x       1
# 7                      tammy gomes      YourMorning       1
# 8                               金马         SYC99999       1
# 9                 Michelle Barnett   JenniferHYChan       1
# 10                    ⏳carol muse⏳            W7VOA       1
# 11                           Jenny  xinjiangchannel       1
# 12                  Guillermo Chan           erveza       1
# 13                       Bart Rule         howroute       1
# 14                               🍑    jenniferatntd       1
# 15                    Agnes Mizere       NCoVAfrica       1
# 16                             IA9      kingjames_x       1
# 17                   yuka*🐝🐑X'back       ChinaDaily       1
# 18             Ministerio de Salud  SeremiSalud_Coq       1
# 19             Ministerio de Salud     PDI_Coquimbo       1
# 20                     Gen X Lefty   HelenBranswell       1
# 21                       Jane West     DazAltTheory       1
# 22                        anshuman          bsindia       1
# 23                   Cristina Popa      YourMorning       1
# 24                       Rod Magat       ABSCBNNews       1
# 25      ǷᎥՈƘʎ_ŁᎥɠҺ੮ Chen⚡첸❃백현이 𝓮𝔁𝓸       ChinaDaily       1
# 26            Raúl Carlos Villordo     CGTNOfficial       1
# 27                             iㅋㅋ     TW_nextmedia       1
# 28             พี่อี้โจ แต่งค่ะ !!        BNK48Post       1
# 29                    Stacey Green  backintherock12       1
# ...                            ...              ...     ...
# 188196        Juan Andrés Rincón G         DrTedros       1
# 188197        Juan Andrés Rincón G    _AfricanUnion       1
# 188198        Juan Andrés Rincón G          NCDCgov       1
# 188199             Busconi Martine  MauriceMartin01       1
# 188200       Pavan Kumar Shastry🇮🇳   ryanfiredragon       1
# 188201                 jose manuel   PneumoniaWuhan       1
# 188202        Juan Andrés Rincón G              WHO       1
# 188203        Juan Andrés Rincón G         DrTedros       1
# 188204        Juan Andrés Rincón G    _AfricanUnion       1
# 188205        Juan Andrés Rincón G          NCDCgov       1
# 188206        Pablo I. Fdez. Muñiz       sanidadgob       1
# 188207        Pablo I. Fdez. Muñiz       sanidadgob       1
# 188208                      Seb 🇫🇷      Conflits_FR       1
# 188209                       Clem🌀      Conflits_FR       1
# 188210        Juan Andrés Rincón G              WHO       1
# 188211        Juan Andrés Rincón G         DrTedros       1
# 188212        Juan Andrés Rincón G    _AfricanUnion       1
# 188213        Juan Andrés Rincón G          NCDCgov       1
# 188214                 jose manuel   PneumoniaWuhan       1
# 188215        Juan Andrés Rincón G              WHO       1
# 188216        Juan Andrés Rincón G         DrTedros       1
# 188217        Juan Andrés Rincón G    _AfricanUnion       1
# 188218        Juan Andrés Rincón G          NCDCgov       1
# 188219                       Kaori       dailynaver       1
# 188220                Lucy Buttons           L0gg0l       1
# 188221                     yumi　ゆみ       DrEricDing       1
# 188222           tabøreciara 🌷🌼🌺🌻🌹       dailynaver       1
# 188223                  Damiendoza    Finanzas_Time       1
# 188224             dreamvillaorion       DrEricDing       1
# 188225                          AF         julio7rc       1
#
# [188226 rows x 3 columns]
# Most frequent user/mention pairs:
#          Mentions                             User  Weight
# 0   Finanzas_Time                          Anto lo     138
# 1   Finanzas_Time                      Dr. Anónimo     115
# 2   Finanzas_Time                              T 1     108
# 3        DrTedros  World Health Organization (WHO)     102
# 4  chrismartenson                     Memento Mori      87
# 5   Finanzas_Time                           TAURUS      84
# 6     Conflits_FR               Brest Newzh ✊🇫🇷🇪🇺🌍      77
# 7     Conflits_FR                Genevieve Grimaud      77
# 8     Conflits_FR             Johan Weylland 🇫🇷 🇺🇸      74
# 9   Finanzas_Time                Ultraderecha 🇺🇸🇧🇷      73

# %%
G = nx.Graph()
for i in range(len(network['User'])):  
   G.add_edge(network['User'][i],network['Mentions'][i],weight=network['Weight'][i])  
     
plt.figure(figsize=(14,14))
d=list(nx.degree(G))
weights = [G.edges[u, v]['weight']/10 for u, v in G.edges()]
size = [d[:][v][1]*100 for v in range(len(d))]  
 
nx.draw_circular(G,node_color='g', node_size=size, edge_color='#909090', with_labels=True, width=weights)
plt.axis('equal')
# Out:
# (-1.108365113333715,
#  1.1353563891931373,
#  -1.105456345362919,
#  1.1054563490233287)

# %%
from bokeh.io import show, output_notebook
from bokeh.models import Plot, Range1d, MultiLine, Circle, HoverTool, TapTool, BoxSelectTool, ColumnDataSource, LabelSet
from bokeh.models.graphs import from_networkx, NodesAndLinkedEdges, EdgesAndLinkedNodes
from bokeh.palettes import Spectral4 
plot = Plot(plot_width=1000, plot_height=1000, x_range=Range1d(-1.1,1.1), y_range=Range1d(-1.1,1.1))
plot.title.text = "Graph Interaction Demonstration" 
plot.add_tools(HoverTool(tooltips=None), TapTool(), BoxSelectTool()) 
graph_renderer = from_networkx(G, nx.circular_layout, scale=1, center=(0,0)) 
graph_renderer.node_renderer.glyph = Circle(size=15, fill_color=Spectral4[0])
graph_renderer.node_renderer.selection_glyph = Circle(size=15, fill_color=Spectral4[2])
graph_renderer.node_renderer.hover_glyph = Circle(size=15, fill_color=Spectral4[1]) 
graph_renderer.edge_renderer.glyph = MultiLine(line_color="#CCCCCC", line_alpha=0.8, line_width=5)
graph_renderer.edge_renderer.selection_glyph = MultiLine(line_color=Spectral4[2], line_width=5)
graph_renderer.edge_renderer.hover_glyph = MultiLine(line_color=Spectral4[1], line_width=5) 
graph_renderer.selection_policy = NodesAndLinkedEdges()
graph_renderer.inspection_policy = EdgesAndLinkedNodes() 
pos =nx.circular_layout(G)
x, y = zip(*pos.values())
node_labels = list(G.nodes)
source = ColumnDataSource({'x': x, 'y': y, 
                           'label': [node_labels[i] for i in range(len(x))]})
labels = LabelSet(x='x', y='y', text='label', source=source,  x_offset=5, y_offset=5) 
plot.renderers.append(labels)
plot.renderers.append(graph_renderer) 
output_notebook()
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1064">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e2b7f3b8-2347-4337-a21d-05de15367264" data-root-id="1003"></div>

# %%
import nltk
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('wordnet')

token_pattern = re.compile(r"(?u)\b\w\w+\b")

class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in word_tokenize(doc) if len(t) >= 2 and re.match("[a-z].*",t) 
                and re.match(token_pattern, t)]
# Out:
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
vocab_size = 2000
print('Tokenizing and counting, this may take a few minutes...')
start_time = time.time()
vectorizer = CountVectorizer(input='content', analyzer='word', stop_words='english',
                             tokenizer=LemmaTokenizer(), max_features=vocab_size, max_df=0.95, min_df=2)
vectors = vectorizer.fit_transform(df.text.values.astype('U'))
vocab_list = vectorizer.get_feature_names()
print('vocab size:', len(vocab_list))

# Random Shuffle
idx = np.arange(vectors.shape[0])
np.random.shuffle(idx)
vectors = vectors[idx]

np.save('vocab', vocab_list)

print('Done. Time elapsed: {:.2f}s'.format(time.time() - start_time))
# Out:
# Tokenizing and counting, this may take a few minutes...
# vocab size: 2000
# Done. Time elapsed: 87.48s

# %%
vectors = sparse.csr_matrix(vectors, dtype=np.float32)

print(type(vectors), vectors.dtype)

n_train = int(0.8 * vectors.shape[0])

# Split Train/Test
train_vectors = vectors[:n_train, :]
test_vectors = vectors[n_train:, :]

# Split test set into validation set (val_vectors) and test set (test_vectors).
n_test = test_vectors.shape[0]
val_vectors = test_vectors[:n_test//2, :]
test_vectors = test_vectors[n_test//2:, :]

print(train_vectors.shape, test_vectors.shape, val_vectors.shape)
# Out:
# <class 'scipy.sparse.csr.csr_matrix'> float32
# (143918, 2000) (17990, 2000) (17990, 2000)

# %%
bucket = sagemaker_session.default_bucket()
prefix = 'twitter_analysis'

train_prefix = os.path.join(prefix, 'train')
val_prefix = os.path.join(prefix, 'val')
output_prefix = os.path.join(prefix, 'output')

s3_train_data = os.path.join('s3://', bucket, train_prefix)
s3_val_data = os.path.join('s3://', bucket, val_prefix)
output_path = os.path.join('s3://', bucket, output_prefix)
print('Training set location', s3_train_data)
print('Validation set location', s3_val_data)
print('Trained model will be saved at', output_path)
# Out:
# Training set location s3://sagemaker-us-east-1-714697274720/twitter_analysis/train
# Validation set location s3://sagemaker-us-east-1-714697274720/twitter_analysis/val
# Trained model will be saved at s3://sagemaker-us-east-1-714697274720/twitter_analysis/output

# %%
def split_convert_upload(sparray, bucket, prefix, fname_template='data_part{}.pbr', n_parts=2):
    import io
    import sagemaker.amazon.common as smac
    
    chunk_size = sparray.shape[0]// n_parts
    for i in range(n_parts):
        # Calculate Start/End Indices
        start = i*chunk_size
        end = (i+1)*chunk_size
        if i+1 == n_parts:
            end = sparray.shape[0]
        
        # Convert to Record Protobuf
        buf = io.BytesIO()
        smac.write_spmatrix_to_sparse_tensor(array=sparray[start:end], file=buf, labels=None)
        buf.seek(0)
        
        # Upload to S3
        fname = os.path.join(prefix, fname_template.format(i))
        boto3.resource('s3').Bucket(bucket).Object(fname).upload_fileobj(buf)
        print('Uploaded data to s3://{}'.format(os.path.join(bucket, fname)))

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri

region_name = boto3.Session().region_name
container = get_image_uri(region_name, 'ntm')

print('Using SageMaker NTM container: {} ({})'.format(container, region_name))
# Out:
# Using SageMaker NTM container: 382416733822.dkr.ecr.us-east-1.amazonaws.com/ntm:1 (us-east-1)

# %%
from sagemaker.session import s3_input
ntm = sagemaker.estimator.Estimator(container,
                                    role, 
                                    train_instance_count=2, 
                                    train_instance_type='ml.c4.xlarge',
                                    output_path=output_path,
                                    sagemaker_session=sagemaker_session)

num_topics = 10
ntm.set_hyperparameters(num_topics=num_topics, feature_dim=vocab_size, mini_batch_size=128, 
                        epochs=100, num_patience_epochs=5, tolerance=0.001)

s3_train = s3_input(s3_train_data, distribution='ShardedByS3Key')

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return true;
# }

# %%
ntm.fit({'train': s3_train, 'test': s3_val_data})
# Out:
# 2020-04-06 18:40:29 Starting - Starting the training job...
# 2020-04-06 18:40:30 Starting - Launching requested ML instances......
# 2020-04-06 18:41:39 Starting - Preparing the instances for training...
# 2020-04-06 18:42:29 Downloading - Downloading input data......
# 2020-04-06 18:43:13 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python2.7/site-packages/pandas/util/nosetester.py:13: DeprecationWarning: Importing from numpy.testing.nosetester is deprecated, import from numpy.testing instead.
#   from numpy.testing import nosetester
# [04/06/2020 18:43:36 INFO 140209060788032] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'num_patience_epochs': u'3', u'clip_gradient': u'Inf', u'encoder_layers': u'auto', u'optimizer': u'adadelta', u'_kvstore': u'auto_gpu', u'rescale_gradient': u'1.0', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'learning_rate': u'0.01', u'_data_format': u'record', u'sub_sample': u'1.0', u'epochs': u'50', u'weight_decay': u'0.0', u'_num_kv_servers': u'auto', u'encoder_layers_activation': u'sigmoid', u'mini_batch_size': u'256', u'tolerance': u'0.001', u'batch_norm': u'false'}
# [04/06/2020 18:43:36 INFO 140209060788032] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'num_patience_epochs': u'5', u'num_topics': u'10', u'epochs': u'100', u'feature_dim': u'2000', u'mini_batch_size': u'128', u'tolerance': u'0.001'}
# [04/06/2020 18:43:36 INFO 140209060788032] Final configuration: {u'optimizer': u'adadelta', u'rescale_gradient': u'1.0', u'_tuning_objective_metric': u'', u'learning_rate': u'0.01', u'clip_gradient': u'Inf', u'feature_dim': u'2000', u'encoder_layers_activation': u'sigmoid', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0', u'num_patience_epochs': u'5', u'epochs': u'100', u'mini_batch_size': u'128', u'num_topics': u'10', u'_num_gpus': u'auto', u'_data_format': u'record', u'sub_sample': u'1.0', u'_kvstore': u'auto_gpu', u'encoder_layers': u'auto', u'tolerance': u'0.001', u'batch_norm': u'false'}
# [04/06/2020 18:43:36 INFO 140209060788032] nvidia-smi took: 0.0251889228821 secs to identify 0 gpus
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python2.7/site-packages/pandas/util/nosetester.py:13: DeprecationWarning: Importing from numpy.testing.nosetester is deprecated, import from numpy.testing instead.
#   from numpy.testing import nosetester
# [04/06/2020 18:43:35 INFO 139700339894080] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'num_patience_epochs': u'3', u'clip_gradient': u'Inf', u'encoder_layers': u'auto', u'optimizer': u'adadelta', u'_kvstore': u'auto_gpu', u'rescale_gradient': u'1.0', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'learning_rate': u'0.01', u'_data_format': u'record', u'sub_sample': u'1.0', u'epochs': u'50', u'weight_decay': u'0.0', u'_num_kv_servers': u'auto', u'encoder_layers_activation': u'sigmoid', u'mini_batch_size': u'256', u'tolerance': u'0.001', u'batch_norm': u'false'}
# [04/06/2020 18:43:35 INFO 139700339894080] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'num_patience_epochs': u'5', u'num_topics': u'10', u'epochs': u'100', u'feature_dim': u'2000', u'mini_batch_size': u'128', u'tolerance': u'0.001'}
# [04/06/2020 18:43:35 INFO 139700339894080] Final configuration: {u'optimizer': u'adadelta', u'rescale_gradient': u'1.0', u'_tuning_objective_metric': u'', u'learning_rate': u'0.01', u'clip_gradient': u'Inf', u'feature_dim': u'2000', u'encoder_layers_activation': u'sigmoid', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0', u'num_patience_epochs': u'5', u'epochs': u'100', u'mini_batch_size': u'128', u'num_topics': u'10', u'_num_gpus': u'auto', u'_data_format': u'record', u'sub_sample': u'1.0', u'_kvstore': u'auto_gpu', u'encoder_layers': u'auto', u'tolerance': u'0.001', u'batch_norm': u'false'}
# [04/06/2020 18:43:35 INFO 139700339894080] nvidia-smi took: 0.0251748561859 secs to identify 0 gpus
# [04/06/2020 18:43:37 INFO 140209060788032] Launching parameter server for role scheduler
# [04/06/2020 18:43:37 INFO 140209060788032] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/e1b211b5-835f-4e82-b70c-626a7bf29a21', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'ntm-2020-04-06-18-40-28-992', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-113-51.ec2.internal', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/962a563d-5c26-4409-beed-390c6fead073', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:714697274720:training-job/ntm-2020-04-06-18-40-28-992', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/06/2020 18:43:37 INFO 140209060788032] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/e1b211b5-835f-4e82-b70c-626a7bf29a21', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.113.51', 'AWS_REGION': 'us-east-1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'ntm-2020-04-06-18-40-28-992', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-113-51.ec2.internal', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/962a563d-5c26-4409-beed-390c6fead073', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '2', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:714697274720:training-job/ntm-2020-04-06-18-40-28-992', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/06/2020 18:43:37 INFO 140209060788032] Launching parameter server for role server
# [04/06/2020 18:43:37 INFO 140209060788032] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/e1b211b5-835f-4e82-b70c-626a7bf29a21', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'ntm-2020-04-06-18-40-28-992', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-113-51.ec2.internal', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/962a563d-5c26-4409-beed-390c6fead073', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:714697274720:training-job/ntm-2020-04-06-18-40-28-992', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/06/2020 18:43:37 INFO 140209060788032] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/e1b211b5-835f-4e82-b70c-626a7bf29a21', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.113.51', 'AWS_REGION': 'us-east-1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'ntm-2020-04-06-18-40-28-992', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-113-51.ec2.internal', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/962a563d-5c26-4409-beed-390c6fead073', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '2', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:714697274720:training-job/ntm-2020-04-06-18-40-28-992', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/06/2020 18:43:37 INFO 140209060788032] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/e1b211b5-835f-4e82-b70c-626a7bf29a21', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.113.51', 'AWS_REGION': 'us-east-1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'ntm-2020-04-06-18-40-28-992', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-113-51.ec2.internal', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/962a563d-5c26-4409-beed-390c6fead073', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '2', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:714697274720:training-job/ntm-2020-04-06-18-40-28-992', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 36 is a shell:scheduler.
# Process 37 is a shell:server.
# Process 1 is a worker.
# [04/06/2020 18:43:37 INFO 140209060788032] Using default worker.
# [2020-04-06 18:43:37.441] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [04/06/2020 18:43:37 INFO 140209060788032] Initializing
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:122: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# [04/06/2020 18:43:37 INFO 140209060788032] None
# [04/06/2020 18:43:37 INFO 140209060788032] vocab.txt
# [04/06/2020 18:43:37 INFO 140209060788032] Vocab file is not provided
# [04/06/2020 18:43:37 INFO 140209060788032] Number of GPUs being used: 0
# [04/06/2020 18:43:37 INFO 140209060788032] Create Store: dist_async
# [04/06/2020 18:43:37 INFO 139700339894080] Launching parameter server for role server
# [04/06/2020 18:43:37 INFO 139700339894080] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/0beaad79-9578-4976-81c8-17a1923684d7', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'ntm-2020-04-06-18-40-28-992', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-67-254.ec2.internal', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/cd5e5f10-f745-450a-b632-7b07185488e0', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:714697274720:training-job/ntm-2020-04-06-18-40-28-992', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/06/2020 18:43:37 INFO 139700339894080] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/0beaad79-9578-4976-81c8-17a1923684d7', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.113.51', 'AWS_REGION': 'us-east-1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'ntm-2020-04-06-18-40-28-992', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-67-254.ec2.internal', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/cd5e5f10-f745-450a-b632-7b07185488e0', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '2', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:714697274720:training-job/ntm-2020-04-06-18-40-28-992', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/06/2020 18:43:37 INFO 139700339894080] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/0beaad79-9578-4976-81c8-17a1923684d7', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.113.51', 'AWS_REGION': 'us-east-1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'ntm-2020-04-06-18-40-28-992', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-67-254.ec2.internal', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/cd5e5f10-f745-450a-b632-7b07185488e0', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '2', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:714697274720:training-job/ntm-2020-04-06-18-40-28-992', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 37 is a shell:server.
# Process 1 is a worker.
# [04/06/2020 18:43:37 INFO 139700339894080] Using default worker.
# [2020-04-06 18:43:37.237] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
#
"num_examples": 563, "num_bytes": 6496788}
# [04/06/2020 18:44:39 INFO 139700339894080] # Finished training epoch 4 on 71962 examples from 563 batches, each of size 128.
# [04/06/2020 18:44:39 INFO 139700339894080] Metrics for Training:
# [04/06/2020 18:44:39 INFO 139700339894080] Loss (name: value) total: 5.3174442434
# [04/06/2020 18:44:39 INFO 139700339894080] Loss (name: value) kld: 0.329967141337
# [04/06/2020 18:44:39 INFO 139700339894080] Loss (name: value) recons: 4.98747708615
# [04/06/2020 18:44:39 INFO 139700339894080] Loss (name: value) logppx: 5.3174442434
# [04/06/2020 18:44:39 INFO 139700339894080] #quality_metric: host=algo-2, epoch=4, train total_loss <loss>=5.3174442434
# [04/06/2020 18:44:39 INFO 139700339894080] Timing: train: 15.24s, val: 0.00s, epoch: 15.25s
# [04/06/2020 18:44:39 INFO 139700339894080] #progress_metric: host=algo-2, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 563, "sum": 563.0, "min": 563}, "Number of Batches Since Last Reset": {"count": 1, "max": 563, "sum": 563.0, "min": 563}, "Number of Records Since Last Reset": {"count": 1, "max": 71962, "sum": 71962.0, "min": 71962}, "Total Batches Seen": {"count": 1, "max": 2252, "sum": 2252.0, "min": 2252}, "Total Records Seen": {"count": 1, "max": 287848, "sum": 287848.0, "min": 287848}, "Max Records Seen Between Resets": {"count": 1, "max": 71962, "sum": 71962.0, "min": 71962}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1586198679.321357, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/NTM", "epoch": 3}, "StartTime": 1586198664.074057}
#
# [04/06/2020 18:44:39 INFO 139700339894080] #throughput_metric: host=algo-2, train throughput=4719.6063084 records/second
# [04/06/2020 18:44:39 INFO 139700339894080]
# [04/06/2020 18:44:39 INFO 139700339894080] # Starting training for epoch 5
# [2020-04-06 18:44:54.272] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 15082, "num_examples": 563, "num_bytes": 6498004}
# [04/06/2020 18:44:54 INFO 140209060788032] # Finished training epoch 5 on 71956 examples from 563 batches, each of size 128.
# [04/06/2020 18:44:54 INFO 140209060788032] Metrics for Training:
# [04/06/2020 18:44:54 INFO 140209060788032] Loss (name: value) total: 5.17764583066
# [04/06/2020 18:44:54 INFO 140209060788032] Loss (name: value) kld: 0.405816590662
# [04/06/2020 18:44:54 INFO 140209060788032] Loss (name: value) recons: 4.77182924176
# [04/06/2020 18:44:54 INFO 140209060788032] Loss (name: value) logppx: 5.17764583066
# [04/06/2020 18:44:54 INFO 140209060788032] #quality_metric: host=algo-1, epoch=5, train total_loss <loss>=5.17764583066
# [04/06/2020 18:44:54 INFO 140209060788032] Timing: train: 15.09s, val: 0.00s, epoch: 15.09s
# [04/06/2020 18:44:54 INFO 140209060788032] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 563, "sum": 563.0, "min": 563}, "Number of Batches Since Last Reset": {"count": 1, "max": 563, "sum": 563.0, "min": 563}, "Number of Records Since Last Reset": {"count": 1, "max": 71956, "sum": 71956.0, "min": 71956}, "Total Batches Seen": {"count": 1, "max": 2815, "sum": 2815.0, "min": 2815}, "Total Records Seen": {"count": 1, "max": 359780, "sum": 359780.0, "min": 359780}, "Max Records Seen Between Resets": {"count": 1, "max": 71956, "sum": 71956.0, "min": 71956}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1586198694.278544, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/NTM", "epoch": 4}, "StartTime": 1586198679.189008}
#
# [04/06/2020 18:44:54 INFO 140209060788032] #throughput_metric: host=algo-1, train throughput=4768.54817679 records/second
# [04/06/2020 18:44:54 INFO 140209060788032]
# [04/06/2020 18:44:54 INFO 140209060788032] # Starting training for epoch 6
# [2020-04-06 18:44:54.424] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 15101, "num_examples": 563, "num_bytes": 6496788}
# [04/06/2020 18:44:54 INFO 139700339894080] # Finished training epoch 5 on 71962 examples from 563 batches, each of size 128.
# [04/06/2020 18:44:54 INFO 139700339894080] Metrics for Training:
# [04/06/2020 18:44:54 INFO 139700339894080] Loss (name: value) total: 5.17711028409
# [04/06/2020 18:44:54 INFO 139700339894080] Loss (name: value) kld: 0.407446806215
# [04/06/2020 18:44:54 INFO 139700339894080] Loss (name: value) recons: 4.7696634802
# [04/06/2020 18:44:54 INFO 139700339894080] Loss (name: value) logppx: 5.17711028409
# [04/06/2020 18:44:54 INFO 139700339894080] #quality_metric: host=algo-2, epoch=5, train total_loss <loss>=5.17711028409
# [04/06/2020 18:44:54 INFO 139700339894080] Timing: train: 15.10s, val: 0.00s, epoch: 15.11s
# [04/06/2020 18:44:54 INFO 139700339894080] #progress_metric: host=algo-2, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 563, "sum": 563.0, "min": 563}, "Number of Batches Since Last Reset": {"count": 1, "max": 563, "sum": 563.0, "min": 563}, "Number of Records Since Last Reset": {"count": 1, "max": 71962, "sum": 71962.0, "min": 71962}, "Total Batches Seen": {"count": 1, "max":
% of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 563, "sum": 563.0, "min": 563}, "Number of Batches Since Last Reset": {"count": 1, "max": 563, "sum": 563.0, "min": 563}, "Number of Records Since Last Reset": {"count": 1, "max": 71956, "sum": 71956.0, "min": 71956}, "Total Batches Seen": {"count": 1, "max": 37721, "sum": 37721.0, "min": 37721}, "Total Records Seen": {"count": 1, "max": 4821052, "sum": 4821052.0, "min": 4821052}, "Max Records Seen Between Resets": {"count": 1, "max": 71956, "sum": 71956.0, "min": 71956}, "Reset Count": {"count": 1, "max": 134, "sum": 134.0, "min": 134}}, "EndTime": 1586199600.367018, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/NTM", "epoch": 66}, "StartTime": 1586199589.026255}
#
# [04/06/2020 19:00:00 INFO 140209060788032] #throughput_metric: host=algo-1, train throughput=6344.81048092 records/second
# [04/06/2020 19:00:00 INFO 140209060788032]
# [04/06/2020 19:00:00 INFO 140209060788032] # Starting training for epoch 68
# [2020-04-06 19:00:11.888] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 203, "duration": 11520, "num_examples": 563, "num_bytes": 6498004}
# [04/06/2020 19:00:11 INFO 140209060788032] # Finished training epoch 68 on 71956 examples from 563 batches, each of size 128.
# [04/06/2020 19:00:11 INFO 140209060788032] Metrics for Training:
# [04/06/2020 19:00:11 INFO 140209060788032] Loss (name: value) total: 4.81520783594
# [04/06/2020 19:00:11 INFO 140209060788032] Loss (name: value) kld: 0.701435495783
# [04/06/2020 19:00:11 INFO 140209060788032] Loss (name: value) recons: 4.11377234082
# [04/06/2020 19:00:11 INFO 140209060788032] Loss (name: value) logppx: 4.81520783594
# [04/06/2020 19:00:11 INFO 140209060788032] #quality_metric: host=algo-1, epoch=68, train total_loss <loss>=4.81520783594
# [04/06/2020 19:00:11 INFO 140209060788032] patience losses:[4.811579296580428, 4.815731643889344, 4.816132176091785, 4.816560931358202, 4.816005425491299] min patience loss:4.81157929658 current loss:4.81520783594 absolute loss difference:0.0036285393615
# [04/06/2020 19:00:11 INFO 140209060788032] Bad epoch: loss has not improved (enough). Bad count:5
# [04/06/2020 19:00:11 INFO 140209060788032] Timing: train: 11.52s, val: 0.00s, epoch: 11.52s
# [04/06/2020 19:00:11 INFO 140209060788032] #progress_metric: host=algo-1, completed 68 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 563, "sum": 563.0, "min": 563}, "Number of Batches Since Last Reset": {"count": 1, "max": 563, "sum": 563.0, "min": 563}, "Number of Records Since Last Reset": {"count": 1, "max": 71956, "sum": 71956.0, "min": 71956}, "Total Batches Seen": {"count": 1, "max": 38284, "sum": 38284.0, "min": 38284}, "Total Records Seen": {"count": 1, "max": 4893008, "sum": 4893008.0, "min": 4893008}, "Max Records Seen Between Resets": {"count": 1, "max": 71956, "sum": 71956.0, "min": 71956}, "Reset Count": {"count": 1, "max": 136, "sum": 136.0, "min": 136}}, "EndTime": 1586199611.890555, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/NTM", "epoch": 67}, "StartTime": 1586199600.367325}
#
# [04/06/2020 19:00:11 INFO 140209060788032] #throughput_metric: host=algo-1, train throughput=6244.32180994 records/second
# [04/06/2020 19:00:11 INFO 140209060788032]
# [04/06/2020 19:00:11 INFO 140209060788032] # Starting training for epoch 69
# [2020-04-06 19:00:23.195] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 206, "duration": 11303, "num_examples": 563, "num_bytes": 6498004}
# [04/06/2020 19:00:23 INFO 140209060788032] # Finished training epoch 69 on 71956 examples from 563 batches, each of size 128.
# [04/06/2020 19:00:23 INFO 140209060788032] Metrics for Training:
# [04/06/2020 19:00:23 INFO 140209060788032] Loss (name: value) total: 4.81481074154
# [04/06/2020 19:00:23 INFO 140209060788032] Loss (name: value) kld: 0.701249518387
# [04/06/2020 19:00:23 INFO 140209060788032] Loss (name: value) recons: 4.11356123144
# [04/06/2020 19:00:23 INFO 140209060788032] Loss (name: value) logppx: 4.81481074154
# [04/06/2020 19:00:23 INFO 140209060788032] #quality_metric: host=algo-1, epoch=69, train total_loss <loss>=4.81481074154
# [04/06/2020 19:00:23 INFO 140209060788032] patience losses:[4.815731643889344, 4.816132176091785, 4.816560931358202, 4.816005425491299, 4.815207835941925] min patience loss:4.81520783594 current loss:4.81481074154 absolute loss difference:0.000397094401331
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1014383.2049369812, "sum": 1014383.2049369812, "min": 1014383.2049369812}, "finalize.time": {"count": 1, "max": 56.88285827636719, "sum": 56.88285827636719, "min": 56.88285827636719}, "initialize.time": {"count": 1, "max": 514.0550136566162, "sum": 514.0550136566162, "min": 514.0550136566162}, "model.serialize.time": {"count": 1, "max": 2.7420520782470703, "sum": 2.7420520782470703, "min": 2.7420520782470703}, "setuptime": {"count": 1, "max": 595.0448513031006, "sum": 595.0448513031006, "min": 595.0448513031006}, "early_stop.time": {"count": 69, "max": 5.296945571899414, "sum": 185.5795383453369, "min": 0.1590251922607422}, "update.time": {"count": 69, "max": 15640.793085098267, "sum": 1005194.5240497589, "min": 11301.96499824524}, "epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "model.score.time": {"count": 1, "max": 7871.596097946167, "sum": 7871.596097946167, "min": 7871.596097946167}}, "EndTime": 1586199631.130669, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/NTM"}, "StartTime": 1586198617.405844}
# 2020-04-06 19:00:39 Uploading - Uploading generated training model
# 2020-04-06 19:00:39 Completed - Training job completed
# [2020-04-06 19:00:30.954] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 7704, "num_examples": 1125, "num_bytes": 12994792}
# [04/06/2020 19:00:30 INFO 139700339894080] Finished scoring on 143872 examples from 1124 batches, each of size 128.
# [04/06/2020 19:00:30 INFO 139700339894080] Metrics for Inference:
# [04/06/2020 19:00:30 INFO 139700339894080] Loss (name: value) total: 4.83061093537
# [04/06/2020 19:00:30 INFO 139700339894080] Loss (name: value) kld: 0.703291874445
# [04/06/2020 19:00:30 INFO 139700339894080] Loss (name: value) recons: 4.12731905934
# [04/06/2020 19:00:30 INFO 139700339894080] Loss (name: value) logppx: 4.83061093537
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1125, "sum": 1125.0, "min": 1125}, "Number of Batches Since Last Reset": {"count": 1, "max": 1125, "sum": 1125.0, "min": 1125}, "Number of Records Since Last Reset": {"count": 1, "max": 143918, "sum": 143918.0, "min": 143918}, "Total Batches Seen": {"count": 1, "max": 1125, "sum": 1125.0, "min": 1125}, "Total Records Seen": {"count": 1, "max": 143918, "sum": 143918.0, "min": 143918}, "Max Records Seen Between Resets": {"count": 1, "max": 143918, "sum": 143918.0, "min": 143918}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1586199630.95552, "Dimensions": {"Host": "algo-2", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "AWS/NTM"}, "StartTime": 1586199623.250121}
#
# [04/06/2020 19:00:30 INFO 139700339894080] #test_score (algo-2) : ('log_perplexity', 4.830610935374087)
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1015349.9472141266, "sum": 1015349.9472141266, "min": 1015349.9472141266}, "finalize.time": {"count": 1, "max": 49.690961837768555, "sum": 49.690961837768555, "min": 49.690961837768555}, "initialize.time": {"count": 1, "max": 709.3968391418457, "sum": 709.3968391418457, "min": 709.3968391418457}, "model.serialize.time": {"count": 1, "max": 2.6819705963134766, "sum": 2.6819705963134766, "min": 2.6819705963134766}, "setuptime": {"count": 1, "max": 1587.083101272583, "sum": 1587.083101272583, "min": 1587.083101272583}, "early_stop.time": {"count": 59, "max": 5.244016647338867, "sum": 152.74357795715332, "min": 0.13184547424316406}, "update.time": {"count": 59, "max": 15665.766954421997, "sum": 892111.7820739746, "min": 14900.25806427002}, "epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "model.score.time": {"count": 1, "max": 7705.319166183472, "sum": 7705.319166183472, "min": 7705.319166183472}}, "EndTime": 1586199630.957243, "Dimensions": {"Host": "algo-2", "Operation": "training", "Algorithm": "AWS/NTM"}, "StartTime": 1586198617.230139}
#
# Training seconds: 2180
# Billable seconds: 2180

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
ntm_predictor = ntm.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# Using already existing model: ntm-2020-04-06-18-40-28-992
# ---------------!

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

ntm_predictor.content_type = 'text/csv'
ntm_predictor.serializer = csv_serializer
ntm_predictor.deserializer = json_deserializer

test_data = np.array(test_vectors.todense())
results = ntm_predictor.predict(test_data[:5])
predictions = np.array([prediction['topic_weights'] for prediction in results['predictions']])

# %%
# %matplotlib inline

fs = 12
topics=pd.DataFrame(predictions.T)
topics.plot(kind='bar', figsize=(16,4), fontsize=fs)
plt.ylabel('Topic assignment', fontsize=fs+2)
plt.xlabel('Topic ID', fontsize=fs+2)
# Out:
# Text(0.5, 0, 'Topic ID')

# %%
import mxnet as mx

model_path= os.path.join(output_prefix, ntm._current_job_name, 'output/model.tar.gz')
boto3.resource('s3').Bucket(bucket).download_file(model_path, 'downloaded_model.tar.gz')

# !tar -xzvf 'downloaded_model.tar.gz'
# !unzip -o model_algo-1

model  =  mx.ndarray.load('params')
W = model['arg:projection_weight']
# Out:
# model_algo-2
# model_algo-1
# Archive:  model_algo-1
#  extracting: meta.json
#  extracting: symbol.json
#  extracting: params

# %%
word_to_id = dict()
for i, v in enumerate(vocab_list):
    word_to_id[v] = i

limit = 24
n_col = 4
counter = 0

plt.figure(figsize=(20,16))
for ind in range(num_topics):

    if counter >= limit:
        break

    title_str = 'Topic{}'.format(ind)

    pvals = mx.nd.softmax(mx.nd.array(W[:, ind])).asnumpy()

    word_freq = dict()
    for k in word_to_id.keys():
        i = word_to_id[k]
        word_freq[k] =pvals[i]

    wordcloud = WordCloud(background_color='white').fit_words(word_freq)

    plt.subplot(limit // n_col, n_col, counter+1)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title(title_str)

    counter +=1

# %%
#Hyperparameter Tuning

# %%
training_image = get_image_uri(boto3.Session().region_name, 'ntm')

s3_input_train = s3_train_data
s3_input_validation = s3_val_data

# Hyperparameter Tuning Job Configuration
tuning_job_config = {
    "Strategy": "Bayesian",
    "HyperParameterTuningJobObjective": {
        "Type": "Minimize",
        "MetricName": "validation:total_loss"
    },
    "ParameterRanges": {
        "CategoricalParameterRanges": [
            {
                "Name": "encoder_layers_activation",
                "Values": [
                    "sigmoid",
                    "tanh",
                    "relu"
                ]
            },
            {
                "Name": "optimizer",
                "Values": [
                    "adagrad",
                    "adam",
                    "rmsprop",
                    "sgd",
                    "adadelta"
                ]
            }
        ],
        "ContinuousParameterRanges": [
            {
                "Name": "learning_rate",
                "MinValue": "0.01",
                "MaxValue": "1.0"
            },
            {
                "Name": "rescale_gradient",
                "MinValue": "0.01",
                "MaxValue": "1.0"
            },
            {
                "Name": "weight_decay",
                "MinValue": "0.01",
                "MaxValue": "1.0"
            }
        ],
        "IntegerParameterRanges": [
            {
                "Name": "mini_batch_size",
                "MinValue": "128",
                "MaxValue": "256"
            }
        ]
    },
    "ResourceLimits": {
        "MaxNumberOfTrainingJobs": 15,
        "MaxParallelTrainingJobs": 10
    },
    "TrainingJobEarlyStoppingType": "Off"
}

training_job_definition = {
    "AlgorithmSpecification": {
        "TrainingImage": training_image,
        "TrainingInputMode": "File"
    },
    "EnableInterContainerTrafficEncryption": False,
    "EnableNetworkIsolation": False,
    "InputDataConfig": [
        {
            "ChannelName": "train",
            "CompressionType": "None",
            "DataSource": {
                "S3DataSource": {
                    "S3DataDistributionType": "FullyReplicated",
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3_train_data
                }
            },
            "InputMode": "File",
            "RecordWrapperType": "None",
            "ShuffleConfig": {
                "Seed": 0
            }
        },
        {
            "ChannelName": "validation",
            "CompressionType": "None",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3_val_data,
                    "S3DataDistributionType": "FullyReplicated"
                }
            },
            "InputMode": "File",
            "RecordWrapperType": "None",
            "ShuffleConfig": {
                "Seed": 0
            }
        }
    ],
    "OutputDataConfig": {
        "S3OutputPath": output_path
    },
    "ResourceConfig": {
        "InstanceCount": 1,
        "InstanceType": "ml.m4.xlarge",
        "VolumeSizeInGB": 1
    },
    "RoleArn": role,
    "StaticHyperParameters": {
        "batch_norm": "false",
        "encoder_layers": "auto",
        "epochs": "100",
        "feature_dim": "2000",
        "num_patience_epochs": "5",
        "num_topics": "10",
        "sub_sample": "1.0",
        "tolerance": "0.001"
    },
    "StoppingCondition": {
        "MaxRuntimeInSeconds": 86400
    }
}

tuning_job_tags = [
    {
        "Key": "Used For",
        "Value": "AI/ML IC Workshop Lab 2"
    },
    {
        "Key": "Created By",
        "Value": "Boto3 SDK"
    },
    {
        "Key": "Production",
        "Value": "no"
    }
]

# %%
from datetime import datetime, date, time
sagemaker_client = boto3.Session().client('sagemaker')

# Append Date/Time to Tuning Job Name
#   - Allows HPT to be run multiple times without code changes.
d = datetime.now()
d.strftime("%y/%m/%d")
tuning_job_name = d.strftime("ISIS-SDK-test-v%y%m%dT%H%M")

sagemaker_client.create_hyper_parameter_tuning_job(HyperParameterTuningJobName = tuning_job_name,
                                                   HyperParameterTuningJobConfig = tuning_job_config,
                                                   TrainingJobDefinition = training_job_definition,
                                                   Tags = tuning_job_tags)
print ("Tuning Job name", tuning_job_name)
# Out:
# ---------------------------------------------------------------------------
# ResourceLimitExceeded                     Traceback (most recent call last)
# <ipython-input-62-726e66728ea7> in <module>()
#      11                                                    HyperParameterTuningJobConfig = tuning_job_config,
#      12                                                    TrainingJobDefinition = training_job_definition,
# ---> 13                                                    Tags = tuning_job_tags)
#      14 print ("Tuning Job name", tuning_job_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     314                     "%s() only accepts keyword arguments." % py_operation_name)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
#     318         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     624             error_code = parsed_response.get("Error", {}).get("Code")
#     625             error_class = self.exceptions.from_code(error_code)
# --> 626             raise error_class(parsed_response, operation_name)
#     627         else:
#     628             return parsed_response
#
# ResourceLimitExceeded: An error occurred (ResourceLimitExceeded) when calling the CreateHyperParameterTuningJob operation: The account-level service limit 'Number of instances across all training jobs' is 4 Instances, with current utilization of 0 Instances and a request delta of 10 Instances. Please contact AWS support to request an increase for this limit.
